# %%
from torch.nn import CrossEntropyLoss, Sigmoid, ReLU, Softsign
from TrainingEnvironments.FeedForwardTrainingEnvironment import FeedForwardTrainingEnvironment
from Datasets.GaussianSample import GaussianData

from Models.MLP import MLP
import torch.optim as optim 
import matplotlib.pyplot as plt

# %%
# Constant Model Parameters
input_shape = 2
hidden_shapes = [2, 2]
output_shape = 2

#Constant Environment Parameters
epochs = 250
batches = 200
batchsize = 10

criterion = CrossEntropyLoss()

# %%
data = GaussianData(output_shape, input_shape)
data.showData()

# %%
# Experiment Shell

# Variable Model Parameters
# Creation of Model and Optimizer

# %% [markdown]
# # Experiment 1

# %%
# Variable Model Parameters
activation_function = ReLU

#Creation of Model and Optimizer
model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Creation and Running of Training Environment
Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 0.6381, Accuracy: 0.5895
# Epoch 10, Loss: 0.0037, Accuracy: 0.9945
# Epoch 20, Loss: 0.1693, Accuracy: 0.9920
# Epoch 30, Loss: 0.0013, Accuracy: 0.9985
# Epoch 40, Loss: 0.0005, Accuracy: 0.9970
# Epoch 50, Loss: 0.0005, Accuracy: 0.9980
# Epoch 60, Loss: 0.0006, Accuracy: 0.9980
# Epoch 70, Loss: 0.0009, Accuracy: 0.9975
# Epoch 80, Loss: 0.0004, Accuracy: 0.9965
# Epoch 90, Loss: 0.0424, Accuracy: 0.9960
# Epoch 100, Loss: 0.0003, Accuracy: 0.9965
# Epoch 110, Loss: 0.0005, Accuracy: 0.9985
# Epoch 120, Loss: 0.0004, Accuracy: 0.9970
# Epoch 130, Loss: 0.0002, Accuracy: 0.9975
# Epoch 140, Loss: 0.0003, Accuracy: 0.9965
# Epoch 150, Loss: 0.0009, Accuracy: 0.9965
# Epoch 160, Loss: 0.0002, Accuracy: 0.9985
# Epoch 170, Loss: 0.0003, Accuracy: 0.9970
# Epoch 180, Loss: 0.0001, Accuracy: 0.9970
# Epoch 190, Loss: 0.0002, Accuracy: 0.9945
# Epoch 200, Loss: 0.0223, Accuracy: 0.9990
# Epoch 210, Loss: 0.0007, Accuracy: 0.9970
# Epoch 220, Loss: 0.0002, Accuracy: 0.9970
# Epoch 230, Loss: 0.0016, Accuracy: 0.9965
# Epoch 240, Loss: 0.0003, Accuracy: 0.9995

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Experiment 2

# %%
activation_function = Sigmoid

model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
criterion = CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 0.6880, Accuracy: 0.5030
# Epoch 10, Loss: 0.7517, Accuracy: 0.6630
# Epoch 20, Loss: 0.0707, Accuracy: 0.9685
# Epoch 30, Loss: 0.2224, Accuracy: 0.9625
# Epoch 40, Loss: 0.1180, Accuracy: 0.9720
# Epoch 50, Loss: 0.1725, Accuracy: 0.9610
# Epoch 60, Loss: 0.0257, Accuracy: 0.9635
# Epoch 70, Loss: 0.1697, Accuracy: 0.9695
# Epoch 80, Loss: 0.0045, Accuracy: 0.9725
# Epoch 90, Loss: 0.0356, Accuracy: 0.9630
# Epoch 100, Loss: 0.0072, Accuracy: 0.9735
# Epoch 110, Loss: 0.3970, Accuracy: 0.9715
# Epoch 120, Loss: 0.2307, Accuracy: 0.9675
# Epoch 130, Loss: 0.0029, Accuracy: 0.9735
# Epoch 140, Loss: 0.0104, Accuracy: 0.9660
# Epoch 150, Loss: 0.1727, Accuracy: 0.9620
# Epoch 160, Loss: 0.0279, Accuracy: 0.9720
# Epoch 170, Loss: 0.0149, Accuracy: 0.9645
# Epoch 180, Loss: 0.1366, Accuracy: 0.9635
# Epoch 190, Loss: 0.0646, Accuracy: 0.9585
# Epoch 200, Loss: 0.0057, Accuracy: 0.9700
# Epoch 210, Loss: 0.0159, Accuracy: 0.9750
# Epoch 220, Loss: 0.1772, Accuracy: 0.9700
# Epoch 230, Loss: 0.4640, Accuracy: 0.9660
# Epoch 240, Loss: 0.0619, Accuracy: 0.9670

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Experiment 3

# %%
activation_function = Softsign

model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
criterion = CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 0.6848, Accuracy: 0.5490
# Epoch 10, Loss: 0.1303, Accuracy: 0.9605
# Epoch 20, Loss: 0.1806, Accuracy: 0.9730
# Epoch 30, Loss: 0.0252, Accuracy: 0.9670
# Epoch 40, Loss: 0.0035, Accuracy: 0.9680
# Epoch 50, Loss: 0.0052, Accuracy: 0.9710
# Epoch 60, Loss: 0.0032, Accuracy: 0.9655
# Epoch 70, Loss: 0.0658, Accuracy: 0.9660
# Epoch 80, Loss: 0.1436, Accuracy: 0.9710
# Epoch 90, Loss: 0.0183, Accuracy: 0.9660
# Epoch 100, Loss: 0.0054, Accuracy: 0.9685
# Epoch 110, Loss: 0.0984, Accuracy: 0.9700
# Epoch 120, Loss: 0.0023, Accuracy: 0.9740
# Epoch 130, Loss: 0.0119, Accuracy: 0.9660
# Epoch 140, Loss: 0.0015, Accuracy: 0.9735
# Epoch 150, Loss: 0.0941, Accuracy: 0.9715
# Epoch 160, Loss: 0.0019, Accuracy: 0.9670
# Epoch 170, Loss: 0.0713, Accuracy: 0.9655
# Epoch 180, Loss: 0.0289, Accuracy: 0.9605
# Epoch 190, Loss: 0.0262, Accuracy: 0.9660
# Epoch 200, Loss: 0.0012, Accuracy: 0.9655
# Epoch 210, Loss: 0.0019, Accuracy: 0.9680
# Epoch 220, Loss: 0.0372, Accuracy: 0.9705
# Epoch 230, Loss: 0.0480, Accuracy: 0.9720
# Epoch 240, Loss: 0.0029, Accuracy: 0.9755

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()
