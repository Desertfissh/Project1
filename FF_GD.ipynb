# %%
from torch.nn import CrossEntropyLoss, Sigmoid, ReLU, Softsign
from TrainingEnvironments.FeedForwardTrainingEnvironment import FeedForwardTrainingEnvironment
from Datasets.GaussianSample import GaussianData

from Models.MLP import MLP
import torch.optim as optim 
import matplotlib.pyplot as plt

# %%
# Constant Model Parameters
input_shape = 10
hidden_shapes = [10, 10, 10]
output_shape = 1028

#Constant Environment Parameters
epochs = 50
batches = 100
batchsize = 10

criterion = CrossEntropyLoss()

# %%
data = GaussianData(output_shape, input_shape)
data.showData()
# Out:
# You can only display two dimensions.

# %%
# Experiment Shell

# Variable Model Parameters
# Creation of Model and Optimizer

# %% [markdown]
# # Experiment 1

# %%
# Variable Model Parameters
activation_function = ReLU

#Creation of Model and Optimizer
model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Creation and Running of Training Environment
Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 6.8797, Accuracy: 0.0000
# Epoch 10, Loss: 7.0005, Accuracy: 0.0020
# Epoch 20, Loss: 6.9767, Accuracy: 0.0020
# Epoch 30, Loss: 6.9534, Accuracy: 0.0010
# Epoch 40, Loss: 6.9153, Accuracy: 0.0020

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Experiment 2

# %%
activation_function = Sigmoid

model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
criterion = CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

epochs = 250
batches = 100
batchsize = 10

Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 7.1269, Accuracy: 0.0000
# Epoch 10, Loss: 6.9874, Accuracy: 0.0010
# Epoch 20, Loss: 6.8936, Accuracy: 0.0010
# Epoch 30, Loss: 6.9340, Accuracy: 0.0010
# Epoch 40, Loss: 6.9487, Accuracy: 0.0010
# Epoch 50, Loss: 6.9104, Accuracy: 0.0010
# Epoch 60, Loss: 6.9996, Accuracy: 0.0010
# Epoch 70, Loss: 6.9508, Accuracy: 0.0000
# Epoch 80, Loss: 6.9544, Accuracy: 0.0030
# Epoch 90, Loss: 6.9581, Accuracy: 0.0000
# Epoch 100, Loss: 6.9644, Accuracy: 0.0000
# Epoch 110, Loss: 6.9545, Accuracy: 0.0000
# Epoch 120, Loss: 6.9633, Accuracy: 0.0010
# Epoch 130, Loss: 6.9339, Accuracy: 0.0010
# Epoch 140, Loss: 6.9582, Accuracy: 0.0010
# Epoch 150, Loss: 6.9168, Accuracy: 0.0000
# Epoch 160, Loss: 6.9536, Accuracy: 0.0030
# Epoch 170, Loss: 6.9582, Accuracy: 0.0000
# Epoch 180, Loss: 6.9158, Accuracy: 0.0030
# Epoch 190, Loss: 6.9527, Accuracy: 0.0000
# Epoch 200, Loss: 6.9471, Accuracy: 0.0010
# Epoch 210, Loss: 6.9998, Accuracy: 0.0020
# Epoch 220, Loss: 6.8964, Accuracy: 0.0010
# Epoch 230, Loss: 6.9249, Accuracy: 0.0010
# Epoch 240, Loss: 6.9413, Accuracy: 0.0020

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Experiment 3

# %%
activation_function = Softsign

model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
criterion = CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

epochs = 250
batches = 100
batchsize = 10

Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 6.9053, Accuracy: 0.0000
# Epoch 10, Loss: 6.9408, Accuracy: 0.0000
# Epoch 20, Loss: 6.9559, Accuracy: 0.0030
# Epoch 30, Loss: 6.9815, Accuracy: 0.0000
# Epoch 40, Loss: 6.8806, Accuracy: 0.0000
# Epoch 50, Loss: 6.9655, Accuracy: 0.0020
# Epoch 60, Loss: 6.9364, Accuracy: 0.0000
# Epoch 70, Loss: 6.8027, Accuracy: 0.0030
# Epoch 80, Loss: 6.7610, Accuracy: 0.0050
# Epoch 90, Loss: 6.4391, Accuracy: 0.0050
# Epoch 100, Loss: 6.4154, Accuracy: 0.0040
# Epoch 110, Loss: 6.5622, Accuracy: 0.0080
# Epoch 120, Loss: 6.3844, Accuracy: 0.0050
# Epoch 130, Loss: 6.0909, Accuracy: 0.0100
# Epoch 140, Loss: 5.8644, Accuracy: 0.0100
# Epoch 150, Loss: 5.9663, Accuracy: 0.0040
# Epoch 160, Loss: 6.1727, Accuracy: 0.0050
# Epoch 170, Loss: 5.6227, Accuracy: 0.0090
# Epoch 180, Loss: 6.0941, Accuracy: 0.0120
# Epoch 190, Loss: 6.0540, Accuracy: 0.0110
# Epoch 200, Loss: 5.8046, Accuracy: 0.0120
# Epoch 210, Loss: 5.7521, Accuracy: 0.0120
# Epoch 220, Loss: 5.7027, Accuracy: 0.0090
# Epoch 230, Loss: 6.3326, Accuracy: 0.0080
# Epoch 240, Loss: 5.4250, Accuracy: 0.0070

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()
