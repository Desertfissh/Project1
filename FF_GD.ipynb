# %%
from torch.nn import CrossEntropyLoss, Sigmoid, ReLU, Softsign
from TrainingEnvironments.FeedForwardTrainingEnvironment import FeedForwardTrainingEnvironment
from Datasets.GaussianSample import GaussianData

from Models.MLP import MLP
import torch.optim as optim 
import matplotlib.pyplot as plt

# %%
# Constant Model Parameters
input_shape = 10
hidden_shapes = [10, 10]
output_shape = 1028

#Constant Environment Parameters
epochs = 50
batches = 100
batchsize = 10

criterion = CrossEntropyLoss()

# %%
data = GaussianData(output_shape, input_shape)
data.showData()
# Out:
# You can only display two dimensions.

# %%
# Experiment Shell

# Variable Model Parameters
# Creation of Model and Optimizer

# %% [markdown]
# # Experiment 1

# %%
# Variable Model Parameters
activation_function = ReLU

#Creation of Model and Optimizer
model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Creation and Running of Training Environment
Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 0.8154, Accuracy: 0.4740
# Epoch 10, Loss: 0.0004, Accuracy: 1.0000
# Epoch 20, Loss: 0.0004, Accuracy: 1.0000
# Epoch 30, Loss: 0.0001, Accuracy: 1.0000
# Epoch 40, Loss: 0.0007, Accuracy: 1.0000

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Experiment 2

# %%
activation_function = Sigmoid

model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
criterion = CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

epochs = 50
batches = 100
batchsize = 10

Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 0.7631, Accuracy: 0.4590
# Epoch 10, Loss: 0.6800, Accuracy: 0.5260
# Epoch 20, Loss: 0.2130, Accuracy: 1.0000
# Epoch 30, Loss: 0.0118, Accuracy: 1.0000
# Epoch 40, Loss: 0.0049, Accuracy: 1.0000

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Experiment 3

# %%
activation_function = Softsign

model = MLP(input_shape, hidden_shapes, output_shape, activation_function)
criterion = CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

epochs = 50
batches = 100
batchsize = 10

Experiment1 = FeedForwardTrainingEnvironment(data, model, criterion, optimizer, epochs, batches, batchsize)
loss_data, accuracy_data, mean_activation_data, std_activation_data = Experiment1.trainModel()
# Out:
# Epoch 0, Loss: 0.7818, Accuracy: 0.4730
# Epoch 10, Loss: 0.0111, Accuracy: 1.0000
# Epoch 20, Loss: 0.0029, Accuracy: 1.0000
# Epoch 30, Loss: 0.0018, Accuracy: 1.0000
# Epoch 40, Loss: 0.0013, Accuracy: 1.0000

# %%
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_data, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(accuracy_data, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

plt.show()

# %%
# Plotting the mean values with error bars representing the standard deviation
plt.figure(figsize=(10, 6))
for layer in range(len(hidden_shapes)):
    plt.errorbar(range(epochs), mean_activation_data[layer], yerr=std_activation_data[0], fmt='-o', capsize=5, capthick=1)


# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Mean Value')
plt.title('Mean Values Across Epochs with Standard Deviation')
plt.legend(['Layer1', 'Layer2', 'Layer3', 'Layer4'])
plt.grid(True)

# Display the plot
plt.show()
